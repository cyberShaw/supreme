# %% [markdown]
# # Expiry date prediction

# %% [markdown]
# ## Data pre-process

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# #set path 
# DATA_PATH = 'C:\\Users\\tharagesh\\Desktop\\NEC\\files\\finale\\'

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# import dataset
df = pd.read_csv('/datasets/dataFinal.csv')

# %%
df.head()
# Out:
#    temperature  humidity  top_ice_accepted  ...       C02    Oxygen  shelf_life
# 0     40.00000  90.00000                 0  ...     0.000  50000.00        6.00
# 1     40.14141  90.05051                 0  ...  1010.101  50303.03        6.25
# 2     40.28283  90.10101                 0  ...  2020.202  50606.06        6.50
# 3     40.42424  90.15152                 0  ...  3030.303  50909.09        6.75
# 4     40.56566  90.20202                 0  ...  4040.404  51212.12        7.00
#
# [5 rows x 8 columns]

# %%
#get column names
columns = df.columns
print(columns)
# Out:
# Index(['temperature', 'humidity', 'top_ice_accepted',
#        'water_sprinkle_accepted', 'ethylene_ppm', 'C02', 'Oxygen',
#        'shelf_life'],
#       dtype='object')

# %%
#separate the dataset
df_ideal = df.loc[:99]
df_moderate = df.loc[100:499]
df_worst = df.loc[500:]
print(df_ideal)
print(df_moderate)
print(df_worst)
# Out:
#     temperature  humidity  top_ice_accepted  ...         C02    Oxygen  shelf_life
# 0      40.00000  90.00000                 0  ...       0.000  50000.00        6.00
# 1      40.14141  90.05051                 0  ...    1010.101  50303.03        6.25
# 2      40.28283  90.10101                 0  ...    2020.202  50606.06        6.50
# 3      40.42424  90.15152                 0  ...    3030.303  50909.09        6.75
# 4      40.56566  90.20202                 0  ...    4040.404  51212.12        7.00
# ..          ...       ...               ...  ...         ...       ...         ...
# 95     53.43434  94.79798                 0  ...   95959.600  78787.88        6.00
# 96     53.57576  94.84848                 0  ...   96969.700  79090.91        6.25
# 97     53.71717  94.89899                 0  ...   97979.800  79393.94        6.50
# 98     53.85859  94.94949                 0  ...   98989.900  79696.97        6.75
# 99     54.00000  95.00000                 0  ...  100000.000  80000.00        7.00
#
# [100 rows x 8 columns]
#      temperature   humidity  ...        Oxygen  shelf_life
# 100     52.00000  80.000000  ...   80000.00000    4.000000
# 101     52.01003  80.025063  ...   82280.70175    4.005013
# 102     52.02005  80.050125  ...   84561.40351    4.010025
# 103     52.03008  80.075188  ...   86842.10526    4.015038
# 104     52.04010  80.100251  ...   89122.80702    4.020050
# ..           ...        ...  ...           ...         ...
# 495     55.95990  89.899749  ...  980877.19300    5.979950
# 496     55.96992  89.924812  ...  983157.89470    5.984962
# 497     55.97995  89.949875  ...  985438.59650    5.989975
# 498     55.98997  89.974937  ...  987719.29820    5.994987
# 499     56.00000  90.000000  ...  990000.00000    6.000000
#
# [400 rows x 8 columns]
#      temperature  humidity  top_ice_accepted  ...        C02     Oxygen  shelf_life
# 500     54.00000  80.00000                 1  ...  1000000.0   100000.0    1.000000
# 501     54.06061  80.10101                 1  ...  1090909.0   109090.9    1.030303
# 502     54.12121  80.20202                 1  ...  1181818.0   118181.8    1.060606
# 503     54.18182  80.30303                 1  ...  1272727.0   127272.7    1.090909
# 504     54.24242  80.40404                 1  ...  1363636.0   136363.6    1.121212
# ..           ...       ...               ...  ...        ...        ...         ...
# 595     59.75758  89.59596                 1  ...  9636363.0   963636.4    3.878788
# 596     59.81818  89.69697                 1  ...  9727272.0   972727.3    3.909091
# 597     59.87879  89.79798                 1  ...  9818181.0   981818.2    3.939394
# 598     59.93939  89.89899                 0  ...  9909090.0   990909.1    3.969697
# 599     60.00000  90.00000                 0  ...  9999999.0  1000000.0    4.000000
#
# [100 rows x 8 columns]

# %%
def shuf_col_ideal(colnam):
    a = df_ideal[colnam]
    a = a.sample(frac=1)
    a.reset_index(inplace=True, drop=True)
    return a

# %%
def shuf_col_moderate(colnam):
    a = df_moderate[colnam]
    a = a.sample(frac=1)
    a.reset_index(inplace=True, drop=True)
    return a

# %%
def shuf_col_worst(colnam):
    a = df_worst[colnam]
    a = a.sample(frac=1)
    a.reset_index(inplace=True, drop=True)
    return a

# %%
#shuffle ideal dataset
a = shuf_col_ideal('temperature')
b = shuf_col_ideal('humidity')
c = shuf_col_ideal('top_ice_accepted')
d = shuf_col_ideal('water_sprinkle_accepted')
e = shuf_col_ideal('ethylene_ppm')
f = shuf_col_ideal('C02')
g = shuf_col_ideal('Oxygen')
h = shuf_col_ideal('shelf_life')

dict_ideal = {'temperature': a, 'humidity': b, 'top_ice_accepted': c, 'water_sprinkle_accepted': d, 'ethylene_ppm': e,'c02': f,'oxygen': g, 'shelf_life': h}  
df_ideal_shuf = pd.DataFrame(dict_ideal)
df_ideal_shuf
# Out:
#     temperature  humidity  top_ice_accepted  ...       c02    oxygen  shelf_life
# 0      40.70707  93.28283                 0  ...  15151.52  66363.64        6.50
# 1      50.18182  93.98990                 0  ...  72727.27  51212.12        6.25
# 2      50.88889  91.01010                 0  ...  86868.69  63333.33        6.50
# 3      49.61616  92.97980                 0  ...  42424.24  60000.00        6.50
# 4      46.78788  95.00000                 0  ...  60606.06  73939.39        6.00
# ..          ...       ...               ...  ...       ...       ...         ...
# 95     41.13131  92.02020                 0  ...  29292.93  51515.15        6.25
# 96     43.53535  91.21212                 0  ...  23232.32  76666.67        7.00
# 97     44.38384  93.83838                 0  ...  12121.21  74545.45        6.75
# 98     41.97980  91.61616                 0  ...  24242.42  52727.27        7.00
# 99     51.03030  90.00000                 0  ...  84848.48  78787.88        6.75
#
# [100 rows x 8 columns]

# %%
#shuffle moderate dataset
a = shuf_col_moderate('temperature')
b = shuf_col_moderate('humidity')
c = shuf_col_moderate('top_ice_accepted')
d = shuf_col_moderate('water_sprinkle_accepted')
e = shuf_col_moderate('ethylene_ppm')
f = shuf_col_moderate('C02')
g = shuf_col_moderate('Oxygen')
h = shuf_col_moderate('shelf_life')

dict_moderate = {'temperature': a, 'humidity': b, 'top_ice_accepted': c, 'water_sprinkle_accepted': d, 'ethylene_ppm': e,'c02': f,'oxygen': g, 'shelf_life': h}  
df_moderate_shuf = pd.DataFrame(dict_moderate)
df_moderate_shuf
# Out:
#      temperature   humidity  ...        oxygen  shelf_life
# 0       53.59398  87.794486  ...  392456.14040    5.132832
# 1       52.72180  82.857143  ...  105087.71930    5.448622
# 2       52.25063  80.451128  ...  727719.29820    4.115288
# 3       52.41103  87.343358  ...  130175.43860    5.403509
# 4       52.36090  86.616541  ...  451754.38600    5.478697
# ..           ...        ...  ...           ...         ...
# 395     53.13283  83.809524  ...  828070.17540    4.852130
# 396     52.83208  87.518797  ...  383333.33330    5.223058
# 397     55.52882  80.250627  ...  251052.63160    4.977444
# 398     53.05263  86.140351  ...  538421.05260    4.175439
# 399     54.20551  88.270677  ...   86842.10526    5.072682
#
# [400 rows x 8 columns]

# %%
#shuffle worst dataset
a = shuf_col_worst('temperature')
b = shuf_col_worst('humidity')
c = shuf_col_worst('top_ice_accepted')
d = shuf_col_worst('water_sprinkle_accepted')
e = shuf_col_worst('ethylene_ppm')
f = shuf_col_worst('C02')
g = shuf_col_worst('Oxygen')
h = shuf_col_worst('shelf_life')

dict_worst = {'temperature': a, 'humidity': b, 'top_ice_accepted': c, 'water_sprinkle_accepted': d, 'ethylene_ppm': e,'c02': f,'oxygen': g, 'shelf_life': h}  
df_worst_shuf = pd.DataFrame(dict_worst)
df_worst_shuf
# Out:
#     temperature  humidity  top_ice_accepted  ...        c02    oxygen  shelf_life
# 0      59.81818  86.26263                 1  ...  8999999.0  527272.7    3.242424
# 1      59.33333  80.10101                 1  ...  1818182.0  800000.0    3.727273
# 2      58.12121  85.55556                 1  ...  4181818.0  145454.5    2.818182
# 3      58.96970  83.63636                 1  ...  3090909.0  390909.1    3.969697
# 4      58.00000  87.27273                 1  ...  2000000.0  663636.4    3.060606
# ..          ...       ...               ...  ...        ...       ...         ...
# 95     54.42424  80.00000                 1  ...  5999999.0  500000.0    2.757576
# 96     56.54545  84.34343                 1  ...  5909090.0  827272.7    1.393939
# 97     54.66667  86.76768                 1  ...  4000000.0  490909.1    3.696970
# 98     57.81818  89.39394                 1  ...  5272727.0  618181.8    1.575758
# 99     56.96970  88.98990                 1  ...  5090909.0  927272.7    2.424242
#
# [100 rows x 8 columns]

# %%
#concatenate ideal, moderate, worst dfs
frames = [df_ideal_shuf, df_moderate_shuf, df_worst_shuf]
result = pd.concat(frames)
result
# Out:
#     temperature  humidity  top_ice_accepted  ...         c02     oxygen  shelf_life
# 0      40.70707  93.28283                 0  ...    15151.52   66363.64    6.500000
# 1      50.18182  93.98990                 0  ...    72727.27   51212.12    6.250000
# 2      50.88889  91.01010                 0  ...    86868.69   63333.33    6.500000
# 3      49.61616  92.97980                 0  ...    42424.24   60000.00    6.500000
# 4      46.78788  95.00000                 0  ...    60606.06   73939.39    6.000000
# ..          ...       ...               ...  ...         ...        ...         ...
# 95     54.42424  80.00000                 1  ...  5999999.00  500000.00    2.757576
# 96     56.54545  84.34343                 1  ...  5909090.00  827272.70    1.393939
# 97     54.66667  86.76768                 1  ...  4000000.00  490909.10    3.696970
# 98     57.81818  89.39394                 1  ...  5272727.00  618181.80    1.575758
# 99     56.96970  88.98990                 1  ...  5090909.00  927272.70    2.424242
#
# [600 rows x 8 columns]

# %%
#shuffle complete dataset

data = result.sample(frac=1)
data.reset_index(inplace=True, drop=True)
# data.to_csv(DATA_PATH+'yeetFinal.csv', index=False)
data
# Out:
#      temperature   humidity  ...       oxygen  shelf_life
# 0       54.58647  85.012531  ...  264736.8421    4.556391
# 1       52.51128  80.025063  ...  928421.0526    5.203008
# 2       57.45455  81.414140  ...  963636.4000    3.424242
# 3       56.42424  86.464650  ...  818181.8000    1.242424
# 4       54.46617  85.914787  ...  333157.8947    5.102757
# ..           ...        ...  ...          ...         ...
# 595     54.64662  85.187970  ...  702631.5789    4.025063
# 596     52.58145  87.067669  ...  800701.7544    5.869674
# 597     50.18182  93.989900  ...   51212.1200    6.250000
# 598     55.95990  87.669173  ...  476842.1053    5.353383
# 599     53.42356  89.423559  ...  157543.8596    4.355890
#
# [600 rows x 8 columns]

# %%
data.describe()
# Out:
#        temperature    humidity  ...          oxygen  shelf_life
# count   600.000000  600.000000  ...      600.000000  600.000000
# mean     53.333333   86.250000  ...   459166.666667    4.833333
# std       3.664050    3.897744  ...   298291.726413    1.327977
# min      40.000000   80.000000  ...    50000.000000    1.000000
# 25%      52.598995   83.001253  ...   173313.403925    4.249373
# 50%      54.000000   86.002506  ...   446323.741250    5.000000
# 75%      55.280705   89.003759  ...   719166.666650    5.750627
# max      60.000000   95.000000  ...  1000000.000000    7.000000
#
# [8 rows x 8 columns]

# %%
sns.pairplot(data, diag_kind="kde")
